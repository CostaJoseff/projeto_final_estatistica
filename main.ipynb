# %%
km = [1, 1, 2, 3, 4, 4, 5, 6, 6, 7]
precos = [2.5, 2.1, 3.1, 3.0, 3.8, 3.2, 4.3, 3.9, 4.4, 4.8]

# %%
from modelos import MRLS

modelo = MRLS(km, precos, "Km", "Preços", "Relação entre KM rodados e preço de venda de carros usados", decimal_precision=1)
# Out:
# 6.8
# 6.6
# 6.6
#
# 7.3999999999999995
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 from modelos import MRLS
# ----> 3 modelo = MRLS(km, precos, "Km", "Preços", "Relação entre KM rodados e preço de venda de carros usados", decimal_precision=1)
#
# File c:\Users\Joseff\Documents\Projeto Estatistica\modelos.py:38, in MRLS.__init__(self, x, y, x_label, y_label, dataset_title, decimal_precision)
#      35 print(self.SQReg)
#      36 print("\n" + str(self.SQRes + self.SQReg))
# ---> 38 assert self.SQTot == (self.SQRes + self.SQReg)
#      40 R2_1 = round(self.SQReg / self.SQTot, self.decimal_precision)
#      41 R2_2 = round((self.SQTot - self.SQRes) / self.SQTot, self.decimal_precision)
#
# AssertionError:

# %%
modelo.scatter_plot()

# %%
print(modelo.table())
# Out:
# Km -|- Preços
# 40 -|- 10000
# 30 -|- 15000
# 30 -|- 12000
# 25 -|- 18000
# 50 -|- 8000
# 60 -|- 10000
# 65 -|- 5000
# 10 -|- 30000
# 15 -|- 25000
# 20 -|- 20000
# 55 -|- 8000
# 40 -|- 15000
# 35 -|- 20000
# 30 -|- 20000

# %%
print(modelo.corr)
# Out:
# -0.899238076723803

# %%
print(modelo)
# Out:
# b0: 29335.97229094508 -|- b1:-385.5517070757051

# %%
print("Km -|- Preco -|- Y predito")
for xi, yi in zip(km, precos):
    print(f"{xi} -|- {yi} -|- {modelo(xi)}")
# Out:
# Km -|- Preco -|- Y predito
# 40 -|- 10000 -|- 13913.904007916875
# 30 -|- 15000 -|- 17769.421078673928
# 30 -|- 12000 -|- 17769.421078673928
# 25 -|- 18000 -|- 19697.179614052453
# 50 -|- 8000 -|- 10058.386937159823
# 60 -|- 10000 -|- 6202.8698664027725
# 65 -|- 5000 -|- 4275.111331024247
# 10 -|- 30000 -|- 25480.45522018803
# 15 -|- 25000 -|- 23552.696684809503
# 20 -|- 20000 -|- 21624.93814943098
# 55 -|- 8000 -|- 8130.628401781298
# 40 -|- 15000 -|- 13913.904007916875
# 35 -|- 20000 -|- 15841.6625432954
# 30 -|- 20000 -|- 17769.421078673928

# %%
modelo.scatter_plot(show_model=True)
